# %% [markdown]
# ### Array factor codebook creation

# %% [markdown]
# The main role of developing this code is for creating a codebook for using at simulated radar.
# By creating and setting a codebook were the array factor has the main lobe
